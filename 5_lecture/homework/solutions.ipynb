# %%
import wget
import pandas as pd

# %% [markdown]
# # 1. Twilio
#
# Stáhni si soubor [twlo.csv](twlo.csv), který obsahuje informace o vývoji ceny akcie firmy [Twilio](https://www.twilio.com/) od začátku roku 2020. Soubr obsahuje informace o otevírací, minimální, maximální a uzavírací ceně za každý den.
#
# Stažení souboru pomocí `wget`:
#
# ```python
# import wget
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/twlo.csv")
# ```
#
# 1. Zjisti, kolik má soubor řádek a kolik sloupců.
# 2. U akcií nás zajímají především nejnovější ceny. Podívej se na poslední řádek souboru.
# 3. Podívej se na 5 řádků s cenami na začátku souboru, využij k tomu *funkci* `iloc` i funkci `head()`.
# 4.  Tentokrát využij způsob dle vlastního výběru :-)
#
# **Dobrovolný doplněk**
#
# *Tato část je jen doplnění, k získání bodu je potřeba zpracovat i dotazy výše :-)*
#
# 5. Počet řádků ulož do proměnné `pocet_radku` jako číslo.
# 6. Pokud *funkci* `iloc` zadáš číslo řádku i číslo sloupce, odkazuješ se na jednu konkrétní hodnotu. Pandas ti tuto hodnotu vrací jako číslo. Načti si tedy první hodnotu zavírací ceny (sloupec `Close`) v souboru a poslední hodnotu zavírací ceny v souboru. Vypočítej, o kolik procent se zvýšila hodnota akcie.
# 7. Vyber si sloupec s maximální cenou akcie (sloupec `High`) za jednotlivé dny pomocí `loc` nebo `iloc` jako sérii. Na sloupec použij funkci `.max()`, abys zjistila maximální zaznamenanou cenu akcie za celé období. Obdobným způsobem použij funkci `.min()` na sloupec `Low`. Z těchto hodnot zjistíš maximální rozsah obchodní ceny akcie, což je základ jednoho z akciových ukazatelů (*price range*).

# %%
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/twlo.csv")
df = pd.read_csv('twlo.csv')

df.head(1)
# Out:
#    Unnamed: 0        Date        Open        High        Low       Close
# 0           0  2020-01-02  100.010002  103.150002  99.660004  103.150002

# %%
# 1
df.shape
# Out:
# (302, 6)

# %%
# 2
df.iloc[-1,:]
# Out:
# Unnamed: 0           301
# Date          2021-03-15
# Open          366.679993
# High          369.970001
# Low            361.01001
# Close         369.579987
# Name: 301, dtype: object

# %%
# 3
print(df.head(5))
df.iloc[:5,:]
# Out:
#    Unnamed: 0        Date        Open        High         Low       Close
# 0           0  2020-01-02  100.010002  103.150002   99.660004  103.150002
# 1           1  2020-01-03  101.099998  104.550003  100.760002  103.519997
# 2           2  2020-01-06  102.739998  107.739998  101.769997  107.459999
# 3           3  2020-01-07  107.629997  109.940002  107.370003  108.059998
# 4           4  2020-01-08  108.800003  110.820000  108.199997  109.389999
#    Unnamed: 0        Date        Open        High         Low       Close
# 0           0  2020-01-02  100.010002  103.150002   99.660004  103.150002
# 1           1  2020-01-03  101.099998  104.550003  100.760002  103.519997
# 2           2  2020-01-06  102.739998  107.739998  101.769997  107.459999
# 3           3  2020-01-07  107.629997  109.940002  107.370003  108.059998
# 4           4  2020-01-08  108.800003  110.820000  108.199997  109.389999

# %%
# 5
pocet_radku = df.shape[0]
pocet_radku
# Out:
# 302

# %%
# 6
first = df.iloc[0,-1]
last = df.iloc[-1,-1]

difference = (abs(last - first) / first) * 100.0
f"Start: {first:.2f}, End: {last:.2f}, -> Change: {difference:.2f}%"
# Out:
# 'Start: 103.15, End: 369.58, -> Change: 258.29%'

# %%
# 7
# Pres iloc nebo loc mi to prijde moc slozite -> df.loc[:,'Low'].min() (obdobne pro max)
f'Price range {df.Low.min():.0f}-{df.High.max():.0f}'
# Out:
# 'Price range 68-457'

# %% [markdown]
# # 2. Hra o trůny
#
# Stáhni si soubor [character-deaths.csv](character-deaths.csv), která obsahuje informace o smrti některých postav z prvních pěti knih románové série Píseň ohně a ledu (A Song of Fire and Ice).
#
# Stažení souboru pomocí `wget`:
#
# ```python
# import wget
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/character-deaths.csv")
# ```
#
# *Pozn. Úkoly se týkají zcela nevýznamných postav, proto je riziko spoileru minimální :-)*
#
# 1. Načti soubor do tabulky (DataFrame) a nastav sloupec `Name` jako index.
# 2. Zobraz si sloupce, které tabulka má. Posledních pět sloupců tvoří zkratky názvů knih a informace o tom, jestli se v knize postava vyskytuje.
# 3. Použij *funkci* `loc` ke zjištění informací o smrti postavy jménem "Hali".
# 4. Použij *funkci* `loc` k zobrazení řádků mezi "Gevin Harlaw" a "Gillam".
# 5. Použij *funkci* `loc` k zobrazení řádků mezi "Gevin Harlaw" a "Gillam" a sloupce `Death Year`.
# 6. Použij *funkci* `loc` k zobrazení řádků mezi "Gevin Harlaw" a "Gillam" a informace o tom, v jakých knihách se postava vyskytuje, tj. vypiš všechny sloupce mezi `GoT` a `DwD`.

# %%
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/character-deaths.csv")

# 1
df = pd.read_csv('character-deaths.csv', index_col = 0)
# nebo pomoci df.set_index('Name'), ale proc to neudelat hned pri nacteni ? :-)

df.head(1)
# Out:
#                Death Year  Gender  GoT  CoK  SoS  FfC  DwD
# Name
# Adrack Humble       300.0       1    0    0    0    0    1

# %%
#2
df.columns
# Out:
# Index(['Death Year', 'Gender', 'GoT', 'CoK', 'SoS', 'FfC', 'DwD'], dtype='object')

# %%
#3
df.loc['Hali']

# %%
#4
df.loc['Gevin Harlaw':"Gillam"]
# Out:
#                      Death Year  Gender  GoT  CoK  SoS  FfC  DwD
# Name
# Gevin Harlaw              299.0       1    0    1    0    0    0
# Ghael                       NaN       1    0    0    1    0    1
# Ghost of High Heart         NaN       0    0    0    1    0    0
# Gillam                      NaN       1    0    0    0    1    0

# %%
#5
df.loc['Gevin Harlaw':"Gillam",'Death Year']
# Out:
# Name
# Gevin Harlaw           299.0
# Ghael                    NaN
# Ghost of High Heart      NaN
# Gillam                   NaN
# Name: Death Year, dtype: float64

# %%
#6
df.loc['Gevin Harlaw':"Gillam",'GoT':'DwD']
# Out:
#                      GoT  CoK  SoS  FfC  DwD
# Name
# Gevin Harlaw           0    1    0    0    0
# Ghael                  0    0    1    0    1
# Ghost of High Heart    0    0    1    0    0
# Gillam                 0    0    0    1    0

# %% [markdown]
# # 3. Vakcíny
#
# Stáhni si soubor [country_vaccinations.csv](country_vaccinations.csv) o průběhu očkování proti nemoci COVID-19.
#
# Stažení souboru pomocí `wget`:
#
# ```python
# import wget
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/country_vaccinations.csv")
# ```
#
# Dále napiš následující dotazy:
#
# 1. Dotaz na počty očkovaných (sloupec `total_vaccinations`) v jednotlivých státech dne `2021-03-10` (s datem pracuj úplně stejně jako s řetězcem, tj. nevyužívej modeul `datetime`, ale vlož do dotazu přímo řetězec).
# 2. Dotaz na řádky, kde `2021-03-10` bylo naočkováno více než 1 mil. obyvatel.
# 3. Podíváme se na extrémní hodnoty. Napiš dotaz na řádky, kde za daný den naočkování více než 100 tisíc lidí nebo naopak méně než 100 lidí.
#
# **Dobrovolný doplněk**
#
# 4. Vypiš informace o očkování za dny `2021-03-10` a `2021-03-11` pro státy `United Kingdom`, `Finland` a `Italy`. Použij např. funkci `isin()`.
# 5. Vypiš informace o očkování pro `Japan` mezi daty `2021-03-03` a `2021-03-09`. Data v tomto formátu můžeš porovnávat pomocí operátorů `>=` a `<=` jako řetězce, tj. opět nemusíš použít modul `datetime`.

# %%
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/country_vaccinations.csv")
df = pd.read_csv('country_vaccinations.csv')

df.head(1)
# Out:
#    country        date  total_vaccinations  daily_vaccinations
# 0  Albania  2021-03-01             14295.0              1081.0

# %%
#1
df[df.date =='2021-03-10']
# Out:
#             country        date  total_vaccinations  daily_vaccinations
# 9           Albania  2021-03-10             21613.0               831.0
# 21          Andorra  2021-03-10              4914.0               264.0
# 35        Argentina  2021-03-10           1774438.0             84735.0
# 49        Australia  2021-03-10            106200.0              7909.0
# 63          Austria  2021-03-10            894895.0             23366.0
# ...             ...         ...                 ...                 ...
# 1303  United States  2021-03-10          95721290.0           2168688.0
# 1317        Uruguay  2021-03-10            147798.0             13331.0
# 1329        Vietnam  2021-03-10                 NaN               875.0
# 1342          Wales  2021-03-10           1256043.0             23580.0
# 1355       Zimbabwe  2021-03-10             35901.0              1133.0
#
# [102 rows x 4 columns]

# %%
#2
df[(df.date =='2021-03-10') & (df.total_vaccinations > 1_000_000)]
# Out:
#                    country        date  total_vaccinations  daily_vaccinations
# 35               Argentina  2021-03-10           1774438.0             84735.0
# 130                Belgium  2021-03-10           1072341.0             23987.0
# 179                 Brazil  2021-03-10          10362487.0            155024.0
# 221                 Canada  2021-03-10           2621289.0             75656.0
# 247                  Chile  2021-03-10           5757809.0            252807.0
# 385                England  2021-03-10          20526312.0            293770.0
# 438                 France  2021-03-10           6427037.0            201468.0
# 451                Germany  2021-03-10           8337410.0            224318.0
# 487                 Greece  2021-03-10           1190723.0             28473.0
# 540                Hungary  2021-03-10           1476985.0             60627.0
# 566                  India  2021-03-10          25685011.0           1295566.0
# ...

# %%
#3
df[(df.total_vaccinations < 100) | (df.total_vaccinations > 100_000)]
# Out:
#         country        date  total_vaccinations  daily_vaccinations
# 22       Angola  2021-03-05                 0.0                 NaN
# 26    Argentina  2021-03-01           1049169.0             46705.0
# 27    Argentina  2021-03-02           1126108.0             54213.0
# 28    Argentina  2021-03-03           1181292.0             57262.0
# 29    Argentina  2021-03-04           1252461.0             60376.0
# ...         ...         ...                 ...                 ...
# 1341      Wales  2021-03-09           1225604.0             22687.0
# 1342      Wales  2021-03-10           1256043.0             23580.0
# 1343      Wales  2021-03-11           1294144.0             24612.0
# 1344      Wales  2021-03-12           1334355.0             26110.0
# 1345      Wales  2021-03-13           1370896.0             28540.0
#
# [740 rows x 4 columns]

# %%
#4
df[(df.date.isin(['2021-03-10','2021-03-11'])) & (df.country.isin(['United Kingdom', 'Finland', 'Italy']))]
# Out:
#              country        date  total_vaccinations  daily_vaccinations
# 424          Finland  2021-03-10            600476.0             16122.0
# 425          Finland  2021-03-11            625039.0             16550.0
# 633            Italy  2021-03-10           6050694.0            175155.0
# 634            Italy  2021-03-11           6259134.0            177451.0
# 1290  United Kingdom  2021-03-10          24405231.0            351257.0
# 1291  United Kingdom  2021-03-11          24759603.0            338103.0

# %%
#5
df[((df.date>= '2021-03-03')&(df.date <= '2021-03-09')) & (df.country == 'Japan')]
# Out:
#     country        date  total_vaccinations  daily_vaccinations
# 640   Japan  2021-03-03             37303.0              2774.0
# 641   Japan  2021-03-04             39174.0              2468.0
# 642   Japan  2021-03-05             46469.0              2563.0
# 643   Japan  2021-03-06                 NaN              3566.0
# 644   Japan  2021-03-07                 NaN              4570.0
# 645   Japan  2021-03-08             70796.0              5573.0
# 646   Japan  2021-03-09            107558.0             10398.0

# %% [markdown]
# # 4. Teplota ve městech
#
# Stáhni si soubor [temperature.csv](temperature.csv), který obsahuje informace o průměrné teplotě v různých městech v **listopadu 2017**.
#
# ```python
# import wget
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/temperature.csv")
# ```
#
# Vypiš si prvních několik řádků, ať si prohlédneš strukturu tabulky.
#
# Dále napiš následující dotazy:
# 1. Dotaz na měření, která byla provedena v Praze. Je na datech něco zvláštního? Napadá tě, čím to může být? [Zde](https://cs.wikipedia.org/wiki/Stupe%C5%88_Fahrenheita) je nápověda.
# 2. Dotaz na měření, ve kterých je teplota (sloupec `AvgTemperature`) vyšší než 80 stupňů.
# 3. Dotaz na měření, ve kterých je teplota vyšší než 60 stupňů a současně bylo měření provedeno v regionu (sloupec `Region`) Evropa (Europe).
# 4. Dotaz na extrémní hodnoty, tj. měření, ve kterých je teplota vyšší než 80 stupňů nebo menší než - 20 stupňů.
#
# **Pokročilá varianta**
#
# Nainstaluj si modul `pytemperature` a zkus si vytvořit nový sloupec, který bude obsahovat průměrnou templotu ve stupních Celsia. Ve svém programu nejprve proveď import modulu `pytemperature`. Nový sloupec pak přidáš do tabulky tak, že nalevo od `=` vložíš tabulku a název nového sloupce do hranatých závorek. Napravo pak můžeš provádět výpočty pomocí již existujících sloupců. Můžeš např. použít funkci `f2c` z modulu `pytemperature`, která převede teplotu ze stupňů Fahrenheita na stupně Celsia.
#
# ```python
# import pytemperature
# df["AvgTemperatureCelsia"] = pytemperature.f2c(df["AvgTemperature"])
# ```
#
# Nyní můžeš zpracovat následující příklady:
#
# 5. Dotaz na měření, ve kterých je teplota (sloupec `AvgTemperatureCelsia`) vyšší než 30 stupňů Celsia.
# 6. Dotaz na měření, ve kterých je teplota vyšší než 15 stupňů Celsia a současně bylo měření provedeno v regionu (sloupec `Region`) Evropa (Europe).
# 7. Dotaz na extrémní hodnoty, tj. měření, ve kterých je teplota vyšší než 30 stupňů Celsia nebo menší než -10 stupňů. Jsou některé hodnoty podezřelé?

# %%
# wget.download("https://raw.githubusercontent.com/pesikj/python-012021/master/zadani/5/temperature.csv")
df = pd.read_csv('temperature.csv', index_col=0)
df.head(1)
# Out:
#             Region  Country     City  Day  AvgTemperature
# Unnamed: 0
# 0           Africa  Algeria  Algiers    1            62.0

# %%
#1
df[df.City=='Prague']
# Out:
#             Region         Country    City  Day  AvgTemperature
# Unnamed: 0
# 2100        Europe  Czech Republic  Prague    1            43.5
# 2101        Europe  Czech Republic  Prague    2            48.5
# 2102        Europe  Czech Republic  Prague    3            44.4
# 2103        Europe  Czech Republic  Prague    4            39.7
# 2104        Europe  Czech Republic  Prague    5            40.6
# 2105        Europe  Czech Republic  Prague    6            42.3
# 2106        Europe  Czech Republic  Prague    7            43.5
# 2107        Europe  Czech Republic  Prague    8            41.4
# 2108        Europe  Czech Republic  Prague    9            43.8
# 2109        Europe  Czech Republic  Prague   10            43.0
# 2110        Europe  Czech Republic  Prague   11            39.5
# 2111        Europe  Czech Republic  Prague   12            36.7
# 2112        Europe  Czech Republic  Prague   13            35.8
# ...

# %%
#2
df[df.AvgTemperature > 80]
# Out:
#                    Region Country             City  Day  AvgTemperature
# Unnamed: 0
# 30                 Africa   Benin          Cotonou    1            81.7
# 31                 Africa   Benin          Cotonou    2            81.8
# 32                 Africa   Benin          Cotonou    3            83.6
# 33                 Africa   Benin          Cotonou    4            83.4
# 34                 Africa   Benin          Cotonou    5            80.3
# ...                   ...     ...              ...  ...             ...
# 8011        North America      US      Brownsville    2            80.8
# 8012        North America      US      Brownsville    3            81.1
# 8015        North America      US      Brownsville    6            80.5
# 8042        North America      US   Corpus Christi    3            80.2
# 8074        North America      US  Dallas Ft Worth    5            80.1
#
# [722 rows x 5 columns]

# %%
#3
df[(df.AvgTemperature > 60)&(df.Region =='Europe')]
# Out:
#             Region   Country       City  Day  AvgTemperature
# Unnamed: 0
# 1932        Europe   Albania     Tirana   13            60.3
# 2402        Europe     Italy       Rome    3            62.2
# 2404        Europe     Italy       Rome    5            60.4
# 2580        Europe  Portugal     Lisbon    1            62.5
# 2581        Europe  Portugal     Lisbon    2            63.2
# 2582        Europe  Portugal     Lisbon    3            61.1
# 2583        Europe  Portugal     Lisbon    4            61.6
# 2602        Europe  Portugal     Lisbon   23            64.2
# 2603        Europe  Portugal     Lisbon   24            62.6
# 2701        Europe     Spain  Barcelona    2            63.8
# 2702        Europe     Spain  Barcelona    3            63.1
# 2703        Europe     Spain  Barcelona    4            63.5
# 2704        Europe     Spain  Barcelona    5            61.6
# 2730        Europe     Spain     Bilbao    1            62.9
# ...

# %%
#4
df[(df.AvgTemperature > 80)|(df.AvgTemperature < -20)]
# Out:
#                    Region Country             City  Day  AvgTemperature
# Unnamed: 0
# 30                 Africa   Benin          Cotonou    1            81.7
# 31                 Africa   Benin          Cotonou    2            81.8
# 32                 Africa   Benin          Cotonou    3            83.6
# 33                 Africa   Benin          Cotonou    4            83.4
# 34                 Africa   Benin          Cotonou    5            80.3
# ...                   ...     ...              ...  ...             ...
# 8011        North America      US      Brownsville    2            80.8
# 8012        North America      US      Brownsville    3            81.1
# 8015        North America      US      Brownsville    6            80.5
# 8042        North America      US   Corpus Christi    3            80.2
# 8074        North America      US  Dallas Ft Worth    5            80.1
#
# [772 rows x 5 columns]

# %%
# !pip install pytemperature
import pytemperature
df["AvgTemperatureCelsia"] = pytemperature.f2c(df["AvgTemperature"])

# %%
#5
df[df.AvgTemperatureCelsia > 30]
# Out:
#                                        Region     Country             City  \
# Unnamed: 0
# 421                                    Africa  Mauritania       Nouakchott
# 430                                    Africa  Mauritania       Nouakchott
# 510                                    Africa     Nigeria           Niamey
# 526                                    Africa     Nigeria           Niamey
# 527                                    Africa     Nigeria           Niamey
# 528                                    Africa     Nigeria           Niamey
# 930                                      Asia       India  Bombay (Mumbai)
# 931                                      Asia       India  Bombay (Mumbai)
# 935                                      Asia       India  Bombay (Mumbai)
# 1247                                     Asia        Laos        Vientiane
# 3990        South/Central America & Carribean       Haiti   Port au Prince
# ...

# %%
#6
df[(df.AvgTemperatureCelsia > 15)&(df.Region =='Europe')]
# Out:
#             Region   Country       City  Day  AvgTemperature  \
# Unnamed: 0
# 1932        Europe   Albania     Tirana   13            60.3
# 2221        Europe    France   Bordeaux    2            59.2
# 2402        Europe     Italy       Rome    3            62.2
# 2404        Europe     Italy       Rome    5            60.4
# 2424        Europe     Italy       Rome   25            59.3
# 2580        Europe  Portugal     Lisbon    1            62.5
# 2581        Europe  Portugal     Lisbon    2            63.2
# 2582        Europe  Portugal     Lisbon    3            61.1
# 2583        Europe  Portugal     Lisbon    4            61.6
# 2590        Europe  Portugal     Lisbon   11            59.1
# 2592        Europe  Portugal     Lisbon   13            59.3
# 2602        Europe  Portugal     Lisbon   23            64.2
# 2603        Europe  Portugal     Lisbon   24            62.6
# 2700        Europe     Spain  Barcelona    1            59.1
# ...

# %%
#7
df[(df.AvgTemperatureCelsia > 30)|(df.AvgTemperatureCelsia < -10)]
# Out:
#                    Region   Country         City  Day  AvgTemperature  \
# Unnamed: 0
# 168                Africa  Ethiopia  Addis Ababa   19           -99.0
# 212                Africa    Gambia       Banjul    3           -99.0
# 213                Africa    Gambia       Banjul    4           -99.0
# 214                Africa    Gambia       Banjul    5           -99.0
# 215                Africa    Gambia       Banjul    6           -99.0
# ...                   ...       ...          ...  ...             ...
# 6455        North America        US  Great Falls    6             7.5
# 6485        North America        US       Helena    6            13.1
# 6486        North America        US       Helena    7             8.7
# 7088        North America        US        Fargo    9            12.7
# 7089        North America        US        Fargo   10            13.1
#
#             AvgTemperatureCelsia
# Unnamed: 0
# 168                       -72.78
# 212                       -72.78
# ...

# %% [markdown]
# # 5. Teplota ve městech podruhé
#
# Pokračuj ve své práci s informacemi o průměrných teplotách. Pokud jsi zpracovala pokročilou variantu, můžeš pracovat s teplotami ve stupních Celsia.
#
# Vypiš si prvních několik řádků, ať si prohlédneš strukturu tabulky. Dále napiš následující dotazy:
#
# 1. Dotaz na řádky z 13. listopadu 2017 (sloupec `Day` musí mít hodnotu 13).
# 1. Dotaz na řádky z 13. listopadu 2017 ze Spojených států amerických (sloupec `Day` musí mít hodnotu 13 a sloupec `Country` hodnotu US). Výsledek dotazu si ulož do nové tabulky a použij ji jako vstup pro následující dotaz.
# 1. Pro data z předchozího dotazu napiš dotaz na řádky ve městech (sloupec `City`) Washington a Phiadelphia.
#
# **Dobrovolný doplněk**
#
# *Tato část je jen doplnění, k získání bodu je potřeba zpracovat i dotazy výše :-)*
#
# Vrať se k pomocné tabulce, kterou jsi vytvořila v bodu 2. Vypiš průměrnou hodnotu ze všech měření, která byla provedena 13. listopadu 2017 na úzení Spojených států amerických. K tomu využij funkci `.mean()`, která funguje stejně jako funkce `.sum()`, kterou jsme si ukazovali na lekci. Pokud znáš základy statistiky, zkus funkci pro medián `.median()` a rozptyl `.var()`.

# %%
df.head(1)
# Out:
#             Region  Country     City  Day  AvgTemperature  \
# Unnamed: 0
# 0           Africa  Algeria  Algiers    1            62.0
#
#             AvgTemperatureCelsia
# Unnamed: 0
# 0                          16.67

# %%
#1
df[df.Day==13]
# Out:
#                    Region                   Country         City  Day  \
# Unnamed: 0
# 12                 Africa                   Algeria      Algiers   13
# 42                 Africa                     Benin      Cotonou   13
# 72                 Africa  Central African Republic       Bangui   13
# 102                Africa                     Congo  Brazzaville   13
# 132                Africa                     Egypt        Cairo   13
# ...                   ...                       ...          ...  ...
# 8652        North America                        US    Green Bay   13
# 8682        North America                        US      Madison   13
# 8712        North America                        US    Milwaukee   13
# 8742        North America                        US       Casper   13
# 8772        North America                        US     Cheyenne   13
#
#             AvgTemperature  AvgTemperatureCelsia
# Unnamed: 0
# 12                    54.1                 12.28
# ...

# %%
#2
filtered = df[(df.Day==13)&(df.Country=='US')]
filtered
# Out:
#                    Region Country        City  Day  AvgTemperature  \
# Unnamed: 0
# 4212        North America      US  Birmingham   13            54.8
# 4242        North America      US  Huntsville   13            52.5
# 4272        North America      US      Mobile   13            61.6
# 4302        North America      US  Montgomery   13            55.1
# 4332        North America      US   Anchorage   13            16.2
# ...                   ...     ...         ...  ...             ...
# 8652        North America      US   Green Bay   13            32.6
# 8682        North America      US     Madison   13            30.0
# 8712        North America      US   Milwaukee   13            36.8
# 8742        North America      US      Casper   13            48.1
# 8772        North America      US    Cheyenne   13            45.7
#
#             AvgTemperatureCelsia
# Unnamed: 0
# 4212                       12.67
# 4242                       11.39
# 4272                       16.44
# ...

# %%
#3
filtered[(filtered.City=='Washington')|(filtered.City=='Philadelphia')]
# Out:
#                    Region Country          City  Day  AvgTemperature  \
# Unnamed: 0
# 4872        North America      US    Washington   13            45.2
# 4902        North America      US    Washington   13            45.2
# 7572        North America      US  Philadelphia   13            41.7
#
#             AvgTemperatureCelsia
# Unnamed: 0
# 4872                        7.33
# 4902                        7.33
# 7572                        5.39

# %%
# Doplneni
# Vrať se k pomocné tabulce, kterou jsi vytvořila v bodu 2. 
# Vypiš průměrnou hodnotu ze všech měření, která byla provedena 13. listopadu 2017 na úzení Spojených států amerických. 
# K tomu využij funkci .mean(), která funguje stejně jako funkce .sum(), kterou jsme si ukazovali na lekci. 
# Pokud znáš základy statistiky, zkus funkci pro medián .median() a rozptyl .var()

df[(df.Day==13)&(df.Country=='US')].mean()

# Pripadne proste vzit jen jeden sloupci
# df[(df.Day==13)&(df.Country=='US')].mean().AvgTemperatureCelsia
# Out:
# Day                     13.000000
# AvgTemperature          47.471895
# AvgTemperatureCelsia     8.595229
# dtype: float64

# %%
df[(df.Day==13)&(df.Country=='US')].median()
# Out:
# Day                     13.00
# AvgTemperature          45.40
# AvgTemperatureCelsia     7.44
# dtype: float64

# %%
df[(df.Day==13)&(df.Country=='US')].var()
# Out:
# Day                       0.000000
# AvgTemperature          149.512297
# AvgTemperatureCelsia     46.143949
# dtype: float64
